# %%
# Standard imports used across examples
import numpy as np
import math
import matplotlib.pyplot as plt
import sys
import os

# Add project root to sys.path so we can import src
# Assuming this notebook is in notebooks/ and project root is one level up
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.append(project_root)

# imports from the project
from src.utils.plotter import plot_single_state
from src.utils.gkp_operator import construct_gkp_operator_angle

N = 60

H = construct_gkp_operator_angle(N, theta=0.0, phi=0.0, backend="numpy")

evals, evecs = np.linalg.eigh(H)
gs = evecs[:, 0]

fig, ax, cax = plot_single_state(gs, title=r"GKP $|0_L\rangle$ Wigner Function")

fig.show()
# Out:
# Generating pre-truncation form of the GKP Operator (N=1000)...

# %%
# Standard imports used across examples
import numpy as np
import math
import matplotlib.pyplot as plt
import sys
import os

# Add project root to sys.path so we can import src
# Assuming this notebook is in notebooks/ and project root is one level up
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.append(project_root)

# imports from the project
from src.utils.plotter import plot_single_state
from src.utils.gkp_operator import construct_gkp_operator_angle

N = 6

H = construct_gkp_operator_angle(N, theta=np.pi/4, phi=0.0, backend="numpy")

evals, evecs = np.linalg.eigh(H)
gs = evecs[:, 0]

fig, ax, cax = plot_single_state(gs)

fig.show()
# Out:
# Generating pre-truncation form of the GKP Operator (N=1000)...

# %%
# Standard imports used across examples
import numpy as np
import math
import matplotlib.pyplot as plt
import sys
import os

# Add project root to sys.path so we can import src
# Assuming this notebook is in notebooks/ and project root is one level up
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.append(project_root)

# imports from the project
from src.utils.plotter import plot_single_state
from src.utils.gkp_operator import construct_gkp_operator_angle, construct_gkp_operator

N = 6

H = construct_gkp_operator(N, alpha=1.0, beta=1.0, backend="numpy")

evals, evecs = np.linalg.eigh(H)
gs = evecs[:, 0]

fig, ax, cax = plot_single_state(gs)

fig.show()
# Out:
# Generating pre-truncation form of the GKP Operator (N=1000)...
